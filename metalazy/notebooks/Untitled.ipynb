# %%
import matplotlib.pyplot as plt
w = 6
h = 5
d = 70
plt.figure(figsize=(w, h), dpi=d)
means = (10, 11, 9)
positions = ['lala','lele','lili']
std = (1, 2, 3)

plt.bar(positions, means, color="w", yerr=std, width=2)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# 	Oracle	MetaLazy	MetaLazy (sem hyperparametros)	MetaLazy (pior classificador)	LazyRF
# 20ng mic	93.36	90.49	90.31	87.77	85.46
# 20ng mac	93.1	90.75	90.05	87.32	85.89
# reut mic	71.96	67.68	66.35	65.65	65.41
# reut mac	37.7	36.46	33.36	29.85	30.67

font = {'family' : 'normal',
        'weight' : 'regular',
        'size'   : 13}

matplotlib.rc('font', **font)

labels = ['20ng mic','20ng mac','reut mic','reut mac']
oracle = [93.36, 93.1, 71.96, 37.7]
metalazy = [90.49, 90.75, 67.68, 36.46]
metalazy_no_hyper = [90.31, 90.05, 66.35, 33.36]
metalazy_worse = [87.77, 87.32, 65.65, 29.85]
lazy = [85.46, 85.89, 65.41, 30.67]

x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x, oracle, width, label='oracle', yerr=[0.46,0.44,0.72,1.39])
rects2 = ax.bar(x+0.15, metalazy, width, label='metalazy', yerr=[0.46,0.44,0.21,1.01])
#rects3 = ax.bar(x+0.30, metalazy_no_hyper, width, label='metalazy (-cooc -weights)', yerr=[0.34,0.31,0.12,1.05])
rects4 = ax.bar(x+0.30, metalazy_worse, width, label='metalazy (-weaker)', yerr=[0.57,0.57,0.26,1.3])
rects4 = ax.bar(x+0.45, lazy, width, label='lazyRF', yerr=[0.55,0.56,0.14,1.41])


# Oracle	MetaLazy	MetaLazy (sem hyperparametros)	LazyRF	MetaLazy (pior classificador)
# 93.36 (0.46)	90.49 (0.46)	90.31 (0.34)	85.46 (0.57)	87.77 (0.55)
# 93.10 (0.44)	90.75 (0.44)	90.05 (0.31)	85.89 (0.57)	87.32 (0.56)
# 71.96 (0.72)	67.68 (0.21)	66.35 (0.12)	65.41 (0.26)	65.65 (0.14)
# 37.70 (1.39)	36.46 (1.01)	33.36 (1.05)	30.67 (1.30)	29.85 (1.41)
# # Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('Scores')
# ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim(ymin=25)
ax.legend()

# w = 10
# h = 5
# d = 70
# plt.figure(figsize=(w, h), dpi=d)


# def autolabel(rects):
#     """Attach a text label above each bar in *rects*, displaying its height."""
#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')


# autolabel(rects1)
# autolabel(rects2)
# autolabel(rects3)
# autolabel(rects4)
fig.tight_layout()
fig.set_size_inches(8,6)

plt.show()
# Out:
# /home/lfmendes/data/mestrado/venv/lib/python3.5/site-packages/matplotlib/axes/_base.py:3449: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# 	Oracle	MetaLazy	MetaLazy (sem hyperparametros)	MetaLazy (pior classificador)	LazyRF
# 20ng mic	93.36	90.49	90.31	87.77	85.46
# 20ng mac	93.1	90.75	90.05	87.32	85.89
# reut mic	71.96	67.68	66.35	65.65	65.41
# reut mac	37.7	36.46	33.36	29.85	30.67

font = {'family' : 'normal',
        'weight' : 'regular',
        'size'   : 13}

matplotlib.rc('font', **font)

labels = ['20ng mic','20ng mac','reut mic','reut mac']
metalazy_no_weight = [90.31, 90.60, 65.62, 34.50]
metalazy = [90.49, 90.75, 67.68, 36.46]
metalazy_no_cooc = [90.36, 90.61, 65.41, 35.62]
metalazy_base = [90.31, 90.05, 66.35, 33.36]
metalazy_worse = [87.77, 87.32, 65.65, 29.85]

x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x, metalazy, width, label='metalazy', yerr=[0.42,0.41,0.72,1.12])
rects2 = ax.bar(x+0.15, metalazy_no_weight, width, label='metalazy (-weight)', yerr=[0.46,0.44,0.21,1.01])
rects3 = ax.bar(x+0.30, metalazy_no_cooc, width, label='metalazy (-cooc)', yerr=[0.34,0.31,0.12,1.05])
rects4 = ax.bar(x+0.45, metalazy_base, width, label='metalazy (-cooc -weight)', yerr=[0.34,0.31,0.20,1.05])
rects5 = ax.bar(x+0.60, metalazy_worse, width, label='metalazy (-weaker)', yerr=[0.57,0.57,0.26,1.3])

# 	MetaLazy complete	MetaLazy with cooc	MetaLazy with weight	MetaLazy base	MetaLazy worst classifier
# 20ng mic	90.49	90.31	90.36	90.31	87.77
# 20ng mac	90.75	90.60	90.61	90.05	87.32
# reut mic	67.68	65.62	65.41	66.35	65.65
# reut mac	36.46	34.50	35.62	33.36	29.85
# 	Oracle	MetaLazy	MetaLazy (sem hyperparametros)	LazyRF	MetaLazy (pior classificador)
# 20ng mic	93.36 (0.46)	90.49 (0.46)	90.31 (0.34)	85.46 (0.57)	87.77 (0.55)
# 20ng mac	93.10 (0.44)	90.75 (0.44)	90.05 (0.31)	85.89 (0.57)	87.32 (0.56)
# reut mic	71.96 (0.72)	67.68 (0.21)	66.35 (0.12)	65.41 (0.26)	65.65 (0.14)
# reut mac	37.70 (1.39)	36.46 (1.01)	33.36 (1.05)	30.67 (1.30)	29.85 (1.41)
# ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim(ymin=25)
ax.legend()

# w = 10
# h = 5
# d = 70
# plt.figure(figsize=(w, h), dpi=d)


# def autolabel(rects):
#     """Attach a text label above each bar in *rects*, displaying its height."""
#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')


# autolabel(rects1)
# autolabel(rects2)
# autolabel(rects3)
# autolabel(rects4)
fig.tight_layout()
fig.set_size_inches(8,6)

plt.show()
# Out:
# /home/lfmendes/data/mestrado/venv/lib/python3.5/site-packages/matplotlib/axes/_base.py:3449: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
x - width/2
# Out:
# array([-0.175,  0.825,  1.825,  2.825,  3.825])

# %%
x + width/2
# Out:
# array([0.175, 1.175, 2.175, 3.175, 4.175])
